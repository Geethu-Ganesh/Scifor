# %% [markdown]
# ### 1)What you understand by Text Processing? Write a code to perform text processing

# %% [markdown]
# Text processing is the automated process of analyzing and sorting unstructured text data to gain valuable insights.The entire process of cleaning and standardization of text, making it noise-free and ready for analysis is known as text preprocessing. Comprised of three steps,
# - Noise Removal
# - Lexicon Normalization
# - Object Standardization

# %%
import nltk
from nltk.stem.porter import *
p_stemmer =PorterStemmer()
words=['run','ran','write','wrote','written','mostly']
for word in words:
    print(word+'-->'+p_stemmer.stem(word))
# Out:
# run-->run
# ran-->ran
# write-->write
# wrote-->wrote
# written-->written
# mostly-->mostli

# %% [markdown]
# ### 2)What you understand by NLP toolkit and spacy library? Write a code in which any one gets used.

# %% [markdown]
# ##### NLTK (Natural Language Toolkit)
# NLTK is a powerful Python library for working with human language data. It provides easy-to-use interfaces to perform various NLP tasks and includes a diverse range of corpora and lexical resources.
# ##### spaCy
# spaCy is another widely used NLP library that is designed for efficiency and production use. It is known for its speed and accuracy and provides pre-trained models for multiple languages.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "Text processing is the automated process of analyzing and sorting unstructured text data to gain valuable insights."
doc = nlp(text)
tokens = [token.text for token in doc]
print("Tokens:", tokens)

# %% [markdown]
# ### 3)Describe Neural Networks and Deep Learning in Depth

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4.what you understand by Hyperparameter Tuning?

# %% [markdown]
# Hyperparameter tuning is the process of optimizing the hyperparameters of a machine learning model to improve its performance. Hyperparameters are configuration settings external to the model that can't be learned from the training data but significantly impact the model's performance. Examples include the learning rate in gradient boosting, the number of hidden layers in a neural network, or the regularization parameter in a support vector machine.
# Common methods are,
# - Grid Search
# - Random Search

# %% [markdown]
# ### 5)What you understand by Ensemble Learning?

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 6)What do you understand by Model Evaluation and Selection ?

# %% [markdown]
# Model evaluation and selection are critical steps in the machine learning pipeline that involve assessing the performance of different models and choosing the best-performing one for a given task.
# - Model Evaluation:
# Choosing appropriate evaluation metrics depends on the nature of the problem (classification, regression, clustering, etc.). Common metrics include accuracy, precision, recall, F1-score for classification; mean squared error or R-squared for regression, etc. cross validation technique also part of this
# - Model selection:
# Depending on the problem, various algorithms may be considered. It's crucial to experiment with multiple algorithms to identify the one that performs best for the specific task.

# %% [markdown]
# ### 7)What you understand by Feature Engineering and Feature selection? What is the difference between them?

# %% [markdown]
# ###### Feature Selection
# The goal of feature selection techniques in machine learning is to find the best set of features that allows one to build optimized models of studied phenomena. It broadly classified into two
#
# - 1)Supervised technique:
# These techniques can be used for labelled data and to identify the relevant features for increasing the efficiency of supervised models like classification and regression. For Example- linear regression, decision tree, SVM, etc.
#
# - 2)Unsupervised technique:
# These techniques can be used for unlabelled data. For Example- K-Means Clustering, Principal Component Analysis, Hierarchical Clustering, etc.
#
# ##### Feature Engineering
# Feature Engineering is a process that involves transforming raw data into features that more precisely represent the underlying problem for a predictive model.This is the first step in developing a predictive machine learning model. It helps increase the model’s accuracy on new, unseen data. It involves data preprocessing, missing value handling etc..
